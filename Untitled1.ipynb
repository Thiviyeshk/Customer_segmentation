# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("mall_customer.csv")
df.head(10)
# Out:
#    CustomerID Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0        1000      M  39.0                59.9                    58.0
# 1        1001      M  34.0                48.4                    37.0
# 2        1002      F  40.0                70.5                    26.0
# 3        1003      F  47.0                81.1                    30.0
# 4        1004      F  33.0                42.1                    58.0
# 5        1005      M  33.0                36.7                    73.0
# 6        1006      F  48.0                90.4                    34.0
# 7        1007      F  41.0                74.8                    35.0
# 8        1008      F  31.0                42.3                    43.0
# 9        1009      M  39.0                48.6                    61.0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1000 non-null   int64
#  1   Gender                  997 non-null    object
#  2   Age                     994 non-null    float64
#  3   Annual Income (k$)      996 non-null    float64
#  4   Spending Score (1-100)  994 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 39.2+ KB
#         CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  1000.000000  994.000000          996.000000              994.000000
# mean   1499.500000   38.935614           57.149096               42.645875
# std     288.819436   13.399880           28.628506               20.101589
# min    1000.000000   18.000000           15.000000                1.000000
# 25%    1249.750000   30.000000           34.975000               31.000000
# 50%    1499.500000   36.000000           49.000000               47.000000
# 75%    1749.250000   44.000000           79.400000               57.000000
# max    1999.000000   80.000000          144.100000               92.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    3
# Age                       6
# Annual Income (k$)        4
# Spending Score (1-100)    6
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              982 non-null    int64
#  1   Gender                  982 non-null    object
#  2   Age                     982 non-null    float64
#  3   Annual Income (k$)      982 non-null    float64
#  4   Spending Score (1-100)  982 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 46.0+ KB
#         CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count   982.000000  982.000000          982.000000              982.000000
# mean   1500.304481   38.958248           57.326782               42.603870
# std     288.698083   13.417748           28.658961               20.121469
# min    1000.000000   18.000000           15.000000                1.000000
# 25%    1251.250000   30.000000           35.125000               31.000000
# 50%    1499.500000   36.000000           49.150000               47.000000
# 75%    1750.750000   44.000000           79.475000               57.000000
# max    1999.000000   80.000000          144.100000               92.000000

# %%
sns.histplot(df['Age'],bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.histplot(df['Age'],bins=20)
# ----> 2 plt.show()
#
# File G:\anaconda\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(df['Age'],bins=20)
plt.show()

# %%
sns.histplot(df['Annual Income (k$)'])
plt.show()

# %%
sns.histplot(df['Spending Score (1-100)'])
plt.show()

# %%
sns.scatterplot(x='Annual Income (k$)', y ='Spending Score (1-100)', data=df)
plt.show()

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
plt.plot(range(1,11), wcss)
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
df['Cluster'] = kmeans.fit_predict(X_scaled)
# Out:
# G:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
plt.scatter(df['Annual Income (k$)'],
            df['Spending Score (1-100)'],
            c=df['Cluster'])
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.title("customer Segmentation")
plt.show()

# %%
df.to_csv("customer_segments.csv", index=False)
